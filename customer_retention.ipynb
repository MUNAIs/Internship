# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel('customer_retention_dataset.xlsx')
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
df.head(10)
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
# 5                Female         31-40 years
# 6                  Male         41-50 yaers
# 7                  Male         41-50 yaers
# 8                Female  Less than 20 years
# 9                Female         31-40 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
# 5                                 Noida
# 6                                 Delhi
# 7                                 Delhi
# 8                                 Solan
# 9                                 Delhi
#
# ...

# %%
df.tail(10)
# Out:
#     1Gender of respondent 2 How old are you?   \
# 259                Female         31-40 years
# 260                Female         31-40 years
# 261                Female         21-30 years
# 262                Female         21-30 years
# 263                  Male         41-50 yaers
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 259                         Greater Noida
# 260                                 Noida
# 261                         Greater Noida
# 262                            Bangalore
# 263                                 Delhi
# 264                                 Solan
# 265                             Ghaziabad
# 266                            Bangalore
# 267                                 Solan
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
df.describe()
# Out:
#        4 What is the Pin Code of where you shop online from?
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# max                                        560037.000000

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
[features for features in df.columns if df[features].isnull().sum()>0]
# Out:
# []

# %%
sns.heatmap(df.isnull(),yticklabels=False)#,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (269, 71)

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df.isnull().any()
# Out:
# 1Gender of respondent                                                   False
# 2 How old are you?                                                      False
# 3 Which city do you shop online from?                                   False
# 4 What is the Pin Code of where you shop online from?                   False
# 5 Since How Long You are Shopping Online ?                              False
#                                                                         ...
# Longer delivery period                                                  False
# Change in website/Application design                                    False
# Frequent disruption when moving from one page to another                False
# Website is as efficient as before                                       False
# Which of the Indian online retailer would you recommend to a friend?    False
# Length: 71, dtype: bool

# %%
df.nunique()
# Out:
# 1Gender of respondent                                                    2
# 2 How old are you?                                                       5
# 3 Which city do you shop online from?                                   11
# 4 What is the Pin Code of where you shop online from?                   39
# 5 Since How Long You are Shopping Online ?                               5
#                                                                         ..
# Longer delivery period                                                   6
# Change in website/Application design                                     7
# Frequent disruption when moving from one page to another                 8
# Website is as efficient as before                                        8
# Which of the Indian online retailer would you recommend to a friend?     8
# Length: 71, dtype: int64

# %%
df['1Gender of respondent'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['4 What is the Pin Code of where you shop online from?'].unique()
# Out:
# array([110009, 110030, 201308, 132001, 530068, 110011, 110018, 173229,
#        110039, 244001, 122018, 201310, 560037, 203207, 250001, 201005,
#        110044, 201306, 560010, 201305, 110042, 132036, 560018, 110008,
#        560002, 201303, 201312, 203202, 560001, 201304, 560003, 110014,
#        560013, 173212, 122009, 201009, 201008, 201001, 203001],
#       dtype=int64)

# %%
df['3 Which city do you shop online from?'].unique()
# Out:
# array(['Delhi', 'Greater Noida', 'Karnal ', 'Bangalore ', 'Noida',
#        'Solan', 'Moradabad', 'Gurgaon ', 'Merrut', 'Ghaziabad',
#        'Bulandshahr'], dtype=object)

# %%
df['37 Net Benefit derived from shopping online can lead to users satisfaction'].unique()
# Out:
# array(['Agree (4)', 'Strongly agree (5)', 'indifferent (3)',
#        'Dis-agree (2)'], dtype=object)

# %%
customer_retention_dataset=df.drop(['Longer delivery period','Change in website/Application design'],axis=1)

# %%
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
corelation=customer_retention_dataset.corr()

# %%
sns.pairplot(customer_retention_dataset)

# %%
sns.displot(customer_retention_dataset['4 What is the Pin Code of where you shop online from?'])

# %%
sns.displot(customer_retention_dataset['3 Which city do you shop online from?'],bins=25)

# %%
sns.displot(customer_retention_dataset['5 Since How Long You are Shopping Online ?'],bins=25)

# %%
City_name=df['3 Which city do you shop online from?'].value_counts().index
City_name
# Out:
# Index(['Delhi', 'Greater Noida', 'Noida', 'Bangalore ', 'Karnal ', 'Solan',
#        'Ghaziabad', 'Gurgaon ', 'Merrut', 'Moradabad', 'Bulandshahr'],
#       dtype='object')

# %%
City_val=df['3 Which city do you shop online from?'].value_counts().values
City_val
# Out:
# array([58, 43, 40, 37, 27, 18, 18, 12,  9,  5,  2], dtype=int64)

# %%
#pie chart Top 4 city that uses online shop more
plt.pie(City_val[:4],labels=City_name[:4])
# Out:
# ([<matplotlib.patches.Wedge at 0x5187801280>,
# ...
#  [Text(0.5722633588828934, 0.9394225077567969, 'Delhi'),
#   Text(-1.0387288777365689, 0.36199767755626333, 'Greater Noida'),
#   Text(-0.4697619781174862, -0.9946475174227032, 'Noida'),
#   Text(0.8736726944436363, -0.6683532172314254, 'Bangalore ')])

# %%
Use_website=df['Easy to use website or application'].value_counts().index
Use_website
# Out:
# Index(['Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com',
#        'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com', 'Amazon.in',
#        'Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com',
#        'Amazon.in, Paytm.com, Myntra.com',
#        'Amazon.in, Flipkart.com, Myntra.com', 'Paytm.com', 'Flipkart.com',
#        'Amazon.in, Paytm.com'],
#       dtype='object')

# %%
website_val=df['Easy to use website or application'].value_counts().values
website_val
# Out:
# array([64, 44, 44, 29, 22, 20, 19, 12,  8,  7], dtype=int64)

# %%
plt.pie(website_val[:3],labels=Use_website[:3])
# Out:
# ([<matplotlib.patches.Wedge at 0x518784a9d0>,
# ...
#  [Text(0.2700340253456176, 1.06634029519457, 'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com'),
#   Text(-1.0073506527883973, -0.4418649820101046, 'Amazon.in, Flipkart.com'),
#   Text(0.6756339882361678, -0.8680545570066952, 'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com')])

# %%
Net_benefit=df['37 Net Benefit derived from shopping online can lead to users satisfaction'].value_counts().index
Net_benefit
# Out:
# Index(['Strongly agree (5)', 'Agree (4)', 'indifferent (3)', 'Dis-agree (2)'], dtype='object')

# %%
Satisfaction_val=df['37 Net Benefit derived from shopping online can lead to users satisfaction'].value_counts().values
Satisfaction_val
# Out:
# array([164,  54,  40,  11], dtype=int64)

# %%
plt.pie(Satisfaction_val[:5],labels=Net_benefit[:5])
# Out:
# ([<matplotlib.patches.Wedge at 0x83765dba30>,
# ...
#  [Text(-0.3715237450659693, 1.0353598924297565, 'Strongly agree (5)'),
#   Text(-0.2733098269877023, -1.0655053911041241, 'Agree (4)'),
#   Text(0.8240169114283445, -0.7286948124421443, 'indifferent (3)'),
#   Text(1.0909354801585682, -0.1409247250527541, 'Dis-agree (2)')])

# %%
Trust=df['38 User satisfaction cannot exist without trust'].value_counts().index
Trust
# Out:
# Index(['Strongly agree (5)', 'Agree (4)', 'Strongly disagree (1)',
#        'Dis-agree (2)', 'indifferent (3)'],
#       dtype='object')

# %%
Trust_val=df['38 User satisfaction cannot exist without trust'].value_counts().values
Trust_val
# Out:
# array([122, 117,  18,   7,   5], dtype=int64)

# %%
plt.pie(Trust_val[:5],labels=Trust[:5])
# Out:
# ([<matplotlib.patches.Wedge at 0x8376630250>,
# ...
#  [Text(0.1600135136943039, 1.088299441989751, 'Strongly agree (5)'),
#   Text(-0.5238394511969324, -0.967260166330495, 'Agree (4)'),
#   Text(0.970302569716644, -0.5181823262146997, 'Strongly disagree (1)'),
#   Text(1.0783912985643123, -0.21696130341786002, 'Dis-agree (2)'),
#   Text(1.0981251157831997, -0.06419680744502963, 'indifferent (3)')])

# %%
Discount=df['30 Online shopping gives monetary benefit and discounts'].value_counts().index
Discount
# Out:
# Index(['Strongly agree (5)', 'Agree (4)', 'indifferent (3)',
#        'Strongly disagree (1)', 'Dis-agree (2)'],
#       dtype='object')

# %%
Discount_val=df['30 Online shopping gives monetary benefit and discounts'].value_counts().values
Discount_val
# Out:
# array([105,  85,  50,  18,  11], dtype=int64)

# %%
plt.pie(Discount_val[:5],labels=Discount[:5])
# Out:
# ([<matplotlib.patches.Wedge at 0x8376683070>,
# ...
#  [Text(0.3715236481285785, 1.0353599272143152, 'Strongly agree (5)'),
#   Text(-1.0496771446369324, -0.328904077242677, 'Agree (4)'),
#   Text(0.33502797616393243, -1.0477386387775816, 'indifferent (3)'),
#   Text(0.9821403497743364, -0.49537897951481996, 'Strongly disagree (1)'),
#   Text(1.0909354801585682, -0.1409247250527541, 'Dis-agree (2)')])

# %%
df.groupby(['4 What is the Pin Code of where you shop online from?','3 Which city do you shop online from?','6 How many times you have made an online purchase in the past 1 year?']).size().reset_index()
# Out:
#     4 What is the Pin Code of where you shop online from?  \
# 0                                              110008
# 1                                              110008
# 2                                              110008
# 3                                              110009
# 4                                              110011
# ..                                                ...
# 71                                             560013
# 72                                             560018
# 73                                             560037
# 74                                             560037
# 75                                             560037
#
#    3 Which city do you shop online from?  \
# 0                                  Delhi
# 1                                  Delhi
# 2                                  Delhi
# 3                                  Delhi
# 4                                  Delhi
# ..                                   ...
# ...

# %%
df.corr()
# Out:
#                                                     4 What is the Pin Code of where you shop online from?
# 4 What is the Pin Code of where you shop online...                                                1.0

# %%
sns.heatmap(df.corr(),cmap="Blues",annot=True)
# Out:
# <AxesSubplot:>

# %%
df.skew()
# Out:
# 1Gender of respondent                                                   0.741028
# 2 How old are you?                                                      0.680987
# 3 Which city do you shop online from?                                   0.313729
# 4 What is the Pin Code of where you shop online from?                   1.748322
# 5 Since How Long You are Shopping Online ?                             -0.276968
#                                                                           ...
# Longer delivery period                                                 -0.147702
# Change in website/Application design                                    0.354163
# Frequent disruption when moving from one page to another               -0.100608
# Website is as efficient as before                                       0.662084
# Which of the Indian online retailer would you recommend to a friend?    0.583614
# Length: 71, dtype: float64
